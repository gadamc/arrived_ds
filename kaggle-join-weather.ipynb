# %%
import pandas as pd

# %%
filename = 'KaggleV2-May-2016_with_new_cols_may5_1338.csv'
no_show = pd.read_csv(filename, encoding='latin')

# %%
weather_dailysummary = 'weather_dailysummary.csv'
weather = pd.read_csv(weather_dailysummary)

# %%
weather.head()
# Out:
#    minpressurem  minhumidity  maxtempi  mintempi  maxpressurei  precipm  \
# 0        1015.1           77      74.1      70.9         30.09      0.3
# 1        1012.8           75      79.1      69.1         30.02      0.0
# 2        1015.5           63      75.1      68.8         30.17      3.0
# 3        1019.5           51      78.5      68.4         30.21      0.0
# 4        1018.8           69      77.5      65.5         30.19      0.0
#
#    mindewptm  meanwindspdm  meandewpti  mintempm    ...      maxwspdm  \
# 0       18.0          14.7        66.2      21.6    ...          38.6
# 1       18.8           8.1        68.8      20.6    ...          30.6
# 2       15.3          21.4        63.3      20.4    ...          38.6
# 3       10.2          13.7        59.2      20.2    ...          29.0
# 4       16.4           6.5        66.2      18.6    ...          20.9
#
#    maxdewptm  meantempi        date_tzname date_mon  date_hour  date_min  \
# ...

# %%
weather['AppointmentDay'] = pd.to_datetime(weather['date_pretty'])

# %%
weather.head()
# Out:
#    minpressurem  minhumidity  maxtempi  mintempi  maxpressurei  precipm  \
# 0        1015.1           77      74.1      70.9         30.09      0.3
# 1        1012.8           75      79.1      69.1         30.02      0.0
# 2        1015.5           63      75.1      68.8         30.17      3.0
# 3        1019.5           51      78.5      68.4         30.21      0.0
# 4        1018.8           69      77.5      65.5         30.19      0.0
#
#    mindewptm  meanwindspdm  meandewpti  mintempm       ...        meantempi  \
# 0       18.0          14.7        66.2      21.6       ...             72.5
# 1       18.8           8.1        68.8      20.6       ...             74.1
# 2       15.3          21.4        63.3      20.4       ...             71.9
# 3       10.2          13.7        59.2      20.2       ...             73.4
# 4       16.4           6.5        66.2      18.6       ...             71.5
#
# ...

# %%
no_show.AppointmentDay = pd.to_datetime(no_show['AppointmentDay'])

# %%
no_show.dtypes
# Out:
# PatientId                        float64
# AppointmentID                      int64
# Gender                            object
# ScheduledDay                      object
# AppointmentDay            datetime64[ns]
# Age                                int64
# Neighbourhood                     object
# Scholarship                        int64
# Hipertension                       int64
# Diabetes                           int64
# Alcoholism                         int64
# Handcap                            int64
# SMS_received                       int64
# No-show                           object
# time_d                            object
# time_d_total_seconds             float64
# a_day_of_week                      int64
# s_day_of_week                      int64
# Neighbourhood_category             int64
# Gender_category                    int64
# no_show                             bool
# scheduled_hour                     int64
# time_d_total_days                  int64
# ...

# %%
no_show.head()
# Out:
#       PatientId  AppointmentID Gender         ScheduledDay AppointmentDay  \
# 0  2.987250e+13        5642903      F  2016-04-29 18:38:08     2016-04-29
# 1  5.589980e+14        5642503      M  2016-04-29 16:08:27     2016-04-29
# 2  4.262960e+12        5642549      F  2016-04-29 16:19:04     2016-04-29
# 3  8.679510e+11        5642828      F  2016-04-29 17:29:31     2016-04-29
# 4  8.841190e+12        5642494      F  2016-04-29 16:07:23     2016-04-29
#
#    Age      Neighbourhood  Scholarship  Hipertension  Diabetes  \
# 0   62    JARDIM DA PENHA            0             1         0
# 1   56    JARDIM DA PENHA            0             0         0
# 2   62      MATA DA PRAIA            0             0         0
# 3    8  PONTAL DE CAMBURI            0             0         0
# 4   56    JARDIM DA PENHA            0             1         1
#
#          ...          No-show                       time_d  \
# 0        ...               No  -1 days +05:21:52.000000000
# ...

# %%
result = pd.merge(no_show, weather, how='left', on='AppointmentDay')

# %%
pd.set_option("display.max_columns",101)

# %%
result.head()
# Out:
#       PatientId  AppointmentID Gender         ScheduledDay AppointmentDay  \
# 0  2.987250e+13        5642903      F  2016-04-29 18:38:08     2016-04-29
# 1  5.589980e+14        5642503      M  2016-04-29 16:08:27     2016-04-29
# 2  4.262960e+12        5642549      F  2016-04-29 16:19:04     2016-04-29
# 3  8.679510e+11        5642828      F  2016-04-29 17:29:31     2016-04-29
# 4  8.841190e+12        5642494      F  2016-04-29 16:07:23     2016-04-29
#
#    Age      Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 0   62    JARDIM DA PENHA            0             1         0           0
# 1   56    JARDIM DA PENHA            0             0         0           0
# 2   62      MATA DA PRAIA            0             0         0           0
# 3    8  PONTAL DE CAMBURI            0             0         0           0
# 4   56    JARDIM DA PENHA            0             1         1           0
#
#    Handcap  SMS_received No-show                       time_d  \
# ...

# %%
no_show[no_show['AppointmentDay'] > pd.to_datetime('20160608', format='%Y%m%d', errors='ignore')]
# Out:
# Empty DataFrame
# Columns: [PatientId, AppointmentID, Gender, ScheduledDay, AppointmentDay, Age, Neighbourhood, Scholarship, Hipertension, Diabetes, Alcoholism, Handcap, SMS_received, No-show, time_d, time_d_total_seconds, a_day_of_week, s_day_of_week, Neighbourhood_category, Gender_category, no_show, scheduled_hour, time_d_total_days]
# Index: []

# %%
result.groupby('AppointmentDay').count()
# Out:
#                 PatientId  AppointmentID  Gender  ScheduledDay   Age  \
# AppointmentDay
# 2016-04-29           3235           3235    3235          3235  3235
# 2016-05-02           4376           4376    4376          4376  4376
# 2016-05-03           4256           4256    4256          4256  4256
# 2016-05-04           4168           4168    4168          4168  4168
# 2016-05-05           4273           4273    4273          4273  4273
# 2016-05-06           3879           3879    3879          3879  3879
# 2016-05-09           4520           4520    4520          4520  4520
# 2016-05-10           4308           4308    4308          4308  4308
# 2016-05-11           4474           4474    4474          4474  4474
# 2016-05-12           4394           4394    4394          4394  4394
# 2016-05-13           3987           3987    3987          3987  3987
# 2016-05-14             39             39      39            39    39
# ...

# %%
no_show.groupby('AppointmentDay').count().sum()
# Out:
# PatientId                 110527
# AppointmentID             110527
# Gender                    110527
# ScheduledDay              110527
# Age                       110527
# Neighbourhood             110527
# Scholarship               110527
# Hipertension              110527
# Diabetes                  110527
# Alcoholism                110527
# Handcap                   110527
# SMS_received              110527
# No-show                   110527
# time_d                    110527
# time_d_total_seconds      110527
# a_day_of_week             110527
# s_day_of_week             110527
# Neighbourhood_category    110527
# Gender_category           110527
# no_show                   110527
# scheduled_hour            110527
# time_d_total_days         110527
# dtype: int64

# %%
no_show['AppointmentDay'].count()
# Out:
# 110527

# %%
result['AppointmentDay'].count()
# Out:
# 110527

# %%
weather.groupby('AppointmentDay').count()
# Out:
#                 minpressurem  minhumidity  maxtempi  mintempi  maxpressurei  \
# AppointmentDay
# 2016-04-29                 1            1         1         1             1
# 2016-04-30                 1            1         1         1             1
# 2016-05-01                 1            1         1         1             1
# 2016-05-02                 1            1         1         1             1
# 2016-05-03                 1            1         1         1             1
# 2016-05-04                 1            1         1         1             1
# 2016-05-05                 1            1         1         1             1
# 2016-05-06                 1            1         1         1             1
# 2016-05-07                 1            1         1         1             1
# 2016-05-08                 1            1         1         1             1
# 2016-05-09                 1            1         1         1             1
# ...

# %%
#eyeball... sms_recieved has affect on no_show rate

no_show.groupby('AppointmentDay').sum()/no_show.groupby('AppointmentDay').count()
# Out:
#                       Age  Alcoholism  AppointmentID  Diabetes  Gender  \
# AppointmentDay
# 2016-04-29      35.704482    0.031839   5.594300e+06  0.074498     NaN
# 2016-05-02      36.825640    0.031764   5.611400e+06  0.073583     NaN
# 2016-05-03      37.371006    0.030075   5.618703e+06  0.074013     NaN
# 2016-05-04      36.660509    0.028311   5.623124e+06  0.065499     NaN
# 2016-05-05      37.126141    0.028317   5.627634e+06  0.071144     NaN
# 2016-05-06      37.533643    0.032483   5.630777e+06  0.073473     NaN
# 2016-05-09      37.086726    0.032522   5.639435e+06  0.069027     NaN
# 2016-05-10      36.871634    0.029248   5.646297e+06  0.078923     NaN
# 2016-05-11      36.669200    0.029504   5.648136e+06  0.069513     NaN
# 2016-05-12      36.656122    0.028903   5.653628e+06  0.069640     NaN
# 2016-05-13      36.722598    0.026837   5.656091e+06  0.078004     NaN
# 2016-05-14      53.589744    0.051282   5.680342e+06  0.179487     NaN
# ...

# %%
result_right = pd.merge(no_show, weather, how='inner', on='AppointmentDay')

# %%
result_right.count()
# Out:
# PatientId                 106248
# AppointmentID             106248
# Gender                    106248
# ScheduledDay              106248
# AppointmentDay            106248
# Age                       106248
# Neighbourhood             106248
# Scholarship               106248
# Hipertension              106248
# Diabetes                  106248
# Alcoholism                106248
# Handcap                   106248
# SMS_received              106248
# No-show                   106248
# time_d                    106248
# time_d_total_seconds      106248
# a_day_of_week             106248
# s_day_of_week             106248
# Neighbourhood_category    106248
# Gender_category           106248
# no_show                   106248
# scheduled_hour            106248
# time_d_total_days         106248
# minpressurem              106248
# minhumidity               106248
# maxtempi                  106248
# mintempi                  106248
# maxpressurei              106248
# ...

# %%
result.to_csv('KaggleV2-May-2016_join_with_weather_may5_1338.csv', index=False)
